# %% [markdown]
# # Introduction

# %% [markdown]
# - I'll analyze movies dataset, that describes the specifications of each film. Like film ID, its director, budget, income , launch year, vote average and count, time..etc and anything is related to thr films
#
# - I'll rangle it by removing outliers like (irrelevent columns , null values , duplications)
#
# - Then I'll analyze and visualize the dataset

# %% [markdown]
# # My questions:

# %% [markdown]
# - what's the relation between release year and vote average ?
# - what's the relation between revenue and vote average ?
# - what's the relation between revenue and budget ?
# - what's the relation between vote count and budget  ?

# %% [markdown]
# # Wrangling steps

# %% [markdown]
# - removing only one row duplicated in ID column
# - removing irrelevent columns like(IMDB_UD - Cast - Homepage - tagline - overview - cast - production_companies - revenue - budget)
# - Replace null values in (genres) column to (not mentioned)
# - change type of (release_date) columns to date_time

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('movies.csv')

df.head(3)
# Out:
#        id    imdb_id  popularity     budget     revenue      original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1   76341  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  262500  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
#
#                                          homepage          director  \
# 0                   http://www.jurassicworld.com/   Colin Trevorrow
# 1                     http://www.madmaxmovie.com/     George Miller
# 2  http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
#
#                       tagline  ...  \
# 0           The park is open.  ...
# 1          What a Lovely Day.  ...
# 2  One Choice Can Destroy You  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.isnull().sum()

# number of null values in each column
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# delete irrelevent columns

df.drop(['imdb_id' , 'cast', 'homepage','tagline', 'overview' ,'original_title'
   ,'production_companies', 'revenue','keywords','budget','director'],axis = 1 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10866 non-null  int64
#  1   popularity    10866 non-null  float64
#  2   runtime       10866 non-null  int64
#  3   genres        10843 non-null  object
#  4   release_date  10866 non-null  object
#  5   vote_count    10866 non-null  int64
#  6   vote_average  10866 non-null  float64
#  7   release_year  10866 non-null  int64
#  8   budget_adj    10866 non-null  float64
#  9   revenue_adj   10866 non-null  float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 849.0+ KB

# %%
# remove only one non-unique id

df['id'].duplicated().sum() # = 1
df.drop_duplicates(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10865 non-null  int64
#  1   popularity    10865 non-null  float64
#  2   runtime       10865 non-null  int64
#  3   genres        10842 non-null  object
#  4   release_date  10865 non-null  object
#  5   vote_count    10865 non-null  int64
#  6   vote_average  10865 non-null  float64
#  7   release_year  10865 non-null  int64
#  8   budget_adj    10865 non-null  float64
#  9   revenue_adj   10865 non-null  float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 933.7+ KB

# %%
# rename revenue_adj to revenue, and budget_adj to budget

df.rename(columns = {'revenue_adj': 'Revenue'}, inplace = True)
df.rename(columns = {'budget_adj': 'Budget'} , inplace = True)

# %%
# replace null names of directors to (unknown)
# replace null values in genres to (none)

df['genres'].fillna('NoNe' , axis = 0 , inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10865 non-null  int64
#  1   popularity    10865 non-null  float64
#  2   runtime       10865 non-null  int64
#  3   genres        10865 non-null  object
#  4   release_date  10865 non-null  object
#  5   vote_count    10865 non-null  int64
#  6   vote_average  10865 non-null  float64
#  7   release_year  10865 non-null  int64
#  8   Budget        10865 non-null  float64
#  9   Revenue       10865 non-null  float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 933.7+ KB

# %%
# convert release date to date_time

df['release_date'] = pd.to_datetime(df['release_date'])

# %%
# now the data is cleaned and ready for analysis

print(df.info())
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10865 entries, 0 to 10865
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            10865 non-null  int64
#  1   popularity    10865 non-null  float64
#  2   runtime       10865 non-null  int64
#  3   genres        10865 non-null  object
#  4   release_date  10865 non-null  datetime64[ns]
#  5   vote_count    10865 non-null  int64
#  6   vote_average  10865 non-null  float64
#  7   release_year  10865 non-null  int64
#  8   Budget        10865 non-null  float64
#  9   Revenue       10865 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# memory usage: 933.7+ KB
# None
#        id  popularity  runtime                                     genres  \
# 0  135397   32.985763      124  Action|Adventure|Science Fiction|Thriller
# 1   76341   28.419936      120  Action|Adventure|Science Fiction|Thriller
# ...

# %%
import matplotlib.pyplot as plt

df.hist(figsize = (40,40))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021EA086BB20>,
# ...
#       dtype=object)

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the last histograms:
#
# - There are more than 8000 movies have very high budget. And if the bidget decreases, the number of movies decreases (Positive relationship).
#
# - There are more than 10000 movies have very high revenue. And if the bidget decreases, the number of movies decreases, less than 2000 movies have less revenue (Positive relationship).
#
# - Most of films have high popularity (more than 10000), and very low percentage of movies that have little popularity.
#
# - there are a positive correlation between the release year and number of frequency, if the number of years increases , the number of movies increases.

# %% [markdown]
# # what's the relation between revenue and vote budget ?

# %%
plot = df.plot(x = 'Revenue' , y='Budget', kind = 'scatter' , color = 'black')
plot.set_xlabel('Revenue')
plot.set_ylabel('Budget')
# Out:
# Text(0, 0.5, 'Budget')

# %% [markdown]
# Conclusion:
#
# there are a positive relashionship between revenue and budget

# %% [markdown]
# # what's the relation between revenue and vote counts ?

# %%
plot = df.plot(x = 'Revenue' , y='vote_count' , kind = 'scatter')
plot.set_xlabel('Revenue')
plot.set_ylabel('vote_count')
# Out:
# Text(0, 0.5, 'vote_count')

# %% [markdown]
# Conclusion:
#
# Most of films that have low revenue have a low votes, And movies with high revenue have high average.

# %% [markdown]
# # what's the relation between release year and vote count ?

# %%
df.plot(x = 'release_year' , y='vote_count' , kind = 'scatter')

plot.set_xlabel('release_year')
plot.set_ylabel('vote_count')
# Out:
# Text(17.606250000000003, 0.5, 'vote_count')

# %% [markdown]
# Conclusion:
#
# Older movies have low vote counts that the new movies that have more vote counts.

# %% [markdown]
# # What's the relation between vote counts and Budget ?

# %%
plot = df.plot(x = 'vote_count' , y='Budget' , kind = 'scatter')

plot.set_xlabel('vote count')
plot.set_ylabel('Budget')
# Out:
# Text(0, 0.5, 'Budget')

# %% [markdown]
# Conclusion:
#
# Many movies that have low vote counts , are made by low budget and the opposite is wright (Positive relationship)

# %%
df = df.to_csv('new_movies.csv')
